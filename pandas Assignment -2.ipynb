# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\Hello\Downloads\imdb_anime.csv")

# %%
data
# Out:
#                                              Title  \
# 0                                        One Piece
# 1      Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                      The Super Mario Bros. Movie
# 3                                  Attack on Titan
# 4                                   Jujutsu Kaisen
# ...                                            ...
# 45712               Demon Slayer: Kimetsu no Yaiba
# 45713               Demon Slayer: Kimetsu no Yaiba
# 45714                                    One Piece
# 45715                                Marmalade Boy
# 45716                              Cinderella Nine
#
#                               Genre User Rating Number of Votes Runtime  \
# 0      Animation, Action, Adventure         8.9         187,689  24 min
# 1      Animation, Action, Adventure         7.4          28,895  99 min
# 2      Animation, Adventure, Comedy         7.1         189,108  92 min
# ...

# %%
data.shape
# Out:
# (45717, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45717 entries, 0 to 45716
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            45717 non-null  object
#  1   Genre            45717 non-null  object
#  2   User Rating      25009 non-null  object
#  3   Number of Votes  25009 non-null  object
#  4   Runtime          32549 non-null  object
#  5   Year             45591 non-null  object
#  6   Summary          23547 non-null  object
#  7   Stars            13676 non-null  object
#  8   Certificate      28694 non-null  object
#  9   Metascore        341 non-null    object
#  10  Gross            25009 non-null  object
#  11  Episode          45717 non-null  object
#  12  Episode Title    34910 non-null  object
# dtypes: object(13)
# memory usage: 4.5+ MB

# %%
data.describe()
# Out:
#            Title                         Genre User Rating Number of Votes  \
# count      45717                         45717       25009           25009
# unique      9851                           201          87            3033
# top     Doraemon  Animation, Action, Adventure         7.6               7
# freq        2758                         13568        1270             567
#
#        Runtime      Year                                            Summary  \
# count    32549     45591                                              23547
# unique     196       740                                              22588
# top     24 min  (1969– )  A young teen who surfs the skies with his ref ...
# freq      9636      2399                                                 25
#
#                                                     Stars Certificate  \
# count                                               13676       28694
# ...

# %%
datax=data.copy()

# %%
datax.fillna({"Title":"no title","Genre":"no genre","User Rating":0,"Number of Votes":0,"Runtime":"10","Year":0,"Summary":"no summary","stars":"no stars","Certificate":"no certificate","Metascore":0,"Gross":10,"Episode Title":"no"},inplace=True)

# %%
datax.replace({"User Rating":{"User Rating":0},"Number of Votes":{"Number of Votes":0},"Runtime":{"Runtime":"10"},"Metascore":{"Metascore":0},"Gross":{"Gross":10},"Episode":{"Episode":0}},inplace=True)

# %%
datax=datax.astype({"User Rating":np.float16,"Metascore":int,"Gross":int,"Episode":int,"Year":str})

# %%
def func(x):
    return x.replace(" min","")
def f(x):
    return int(x)
def f1(x):
    return x.replace(",","")
datac["Runtime"]=datac["Runtime"].map(func).map(f1).map(f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 7
#       5 def f1(x):
#       6     return x.replace(",","")
# ----> 7 datac["Runtime"]=datac["Runtime"].map(func).map(f1).map(f)
#
# NameError: name 'datac' is not defined

# %%
def func(x):
    return x.replace(" min","")
def f(x):
    return int(x)
def f1(x):
    return x.replace(",","")
def f2(x):
    return str(x)
datac["Number of Votes"]=datac["Number of Votes"].map(f2).map(func).map(f1).map(f)

# %%
datax.head()
# Out:
#                                          Title                         Genre  \
# 0                                    One Piece  Animation, Action, Adventure
# 1  Teenage Mutant Ninja Turtles: Mutant Mayhem  Animation, Action, Adventure
# 2                  The Super Mario Bros. Movie  Animation, Adventure, Comedy
# 3                              Attack on Titan  Animation, Action, Adventure
# 4                               Jujutsu Kaisen  Animation, Action, Adventure
#
#    User Rating Number of Votes Runtime         Year  \
# 0     8.898438         187,689  24 min     (1999– )
# 1     7.398438          28,895  99 min       (2023)
# 2     7.101562         189,108  92 min       (2023)
# 3     9.101562         434,457  24 min  (2013–2023)
# 4     8.500000          82,909  24 min     (2020– )
#
#                                              Summary  \
# 0  Follows the adventures of Monkey D. Luffy and ...
# 1  The film follows the Turtle brothers as they w...
# ...

# %%
#1)how many unique animes  are there ?
x=datax["Title"].nunique()

# %%
x
# Out:
# 9851

# %%
#2) which anime has the highest user rating?
a=datax["User Rating"].max()
datax.loc[datax["User Rating"]==a,["Title"]]
# Out:
#                                Title
# 13656                    Idaten Jump
# 17874                   Vinland Saga
# 22753                Attack on Titan
# 34677                Hunter x Hunter
# 39614  Legend of the Galactic Heroes
# 45689                Attack on Titan

# %%
#3) which animes having the ratings between 7.0 to 9 ?
datax.loc[(datax["User Rating"]>=7.0) & (datax["User Rating"]<=9),["Title"]]
# Out:
#                                              Title
# 0                                        One Piece
# 1      Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                      The Super Mario Bros. Movie
# 4                                   Jujutsu Kaisen
# 6                   Demon Slayer: Kimetsu no Yaiba
# ...                                            ...
# 45709               Demon Slayer: Kimetsu no Yaiba
# 45710               Demon Slayer: Kimetsu no Yaiba
# 45711               Demon Slayer: Kimetsu no Yaiba
# 45712               Demon Slayer: Kimetsu no Yaiba
# 45713               Demon Slayer: Kimetsu no Yaiba
#
# [15655 rows x 1 columns]

# %%
#4) which anime has highest and lowest runtime?
x=datax["Runtime"].max()
y=datax["Runtime"].min()
high=datax.loc[datax["Runtime"]==x,["Title"]]
low=datax.loc[datax["Runtime"]==y,["Title"]]
print(high)
# Out:
#                                                   Title
# 1           Teenage Mutant Ninja Turtles: Mutant Mayhem
# 503                              Pokémon the Movie 2000
# 686                       Josee, the Tiger and the Fish
# 842         Teenage Mutant Ninja Turtles: Mutant Mayhem
# 1341                             Pokémon the Movie 2000
# 1524                      Josee, the Tiger and the Fish
# 1799        The Seven Deadly Sins: Prisoners of the Sky
# 1953                              Space Adventure Cobra
# 2010  Doraemon The Movie: Nobita's Great Battle of t...
# 2086                 Doraemon: Nobita's Dorabian Nights
# 2235                             Child of Kamiari Month
# 2430                   Love Live! The School Idol Movie
# 2435             Detective Conan: The Fourteenth Target
# 2497                         The Princess and the Pilot
# 2515              Professor Layton and the Eternal Diva
# 2602  Anohana the Movie: The Flower We Saw That Day ...
# ...

# %%
print(low)
# Out:
#                             Title
# 2809                   Ani*Kuri15
# 3588                Henkei Shoujo
# 3708   Gloomy the Naughty Grizzly
# 4548                      Usavich
# 4792                 Tokino Kousa
# ...                           ...
# 23772  Gloomy the Naughty Grizzly
# 23773  Gloomy the Naughty Grizzly
# 23774  Gloomy the Naughty Grizzly
# 23775  Gloomy the Naughty Grizzly
# 33433                  Ani*Kuri15
#
# [149 rows x 1 columns]

# %%
#5)what is the run time difference betwwen "ONE PIECE " and "SUPER MARIO BROS MOVIE"?

# %%
#6) which is the oldest anime?

# %%
#7>what are the animes released in year 2023?

def sub(s2):
    s1="2023"
    if(len(s2)<=6):
        if s1 in s2:
            return True
        return False
    return False
a=datax["Year"].map(sub)
b=a.values
c=datax[b]
c[["Title"]]
# Out:
#                                              Title
# 1      Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                      The Super Mario Bros. Movie
# 13                           The Boy and the Heron
# 21                    Ruby Gillman, Teenage Kraken
# 42                     Resident Evil: Death Island
# ...                                            ...
# 7965                                 Yomawari Neko
# 8558          Girls und Panzer das Finale: Part IV
# 8605                        Jinzô Mahô Shôjo Kaini
# 8840                             The Dog & The Boy
# 10314                           The Floating World
#
# [105 rows x 1 columns]

# %%
#8) what is the average user rating of all the animes whose genre is action.

def sub(s2):
    s1="Action"
    if s1 in s2:
        return True
    return False

a=datax["Genre"].map(sub)
b=a.values
c=datax[b]
c["User Rating"].mean()
# Out:
# inf

# %%
#9>which anime has the least gross price?
a=datax["Gross"].min()
datax.loc[datax["Gross"]==a,["Title"]]
# Out:
#                                                    Title
# 3233                                          Show Time!
# 5620                                   The Peasant Noble
# 5714   Meitantei Conan Magic File 4: Osaka okonomiyak...
# 6142   Fist of the North Star Legennd of Heroes - Spe...
# 6236                                     Shakotan Boogie
# ...                                                  ...
# 45600                                    Girl Beats Boys
# 45601                                    Girl Beats Boys
# 45602                                    Girl Beats Boys
# 45606                                    Girl Beats Boys
# 45608                                    Girl Beats Boys
#
# [168 rows x 1 columns]

# %%
#10>which anime has the highest gross price?
x=datax["Gross"].max()
datax.loc[datax["Gross"]==x,["Title","Gross"]]
# Out:
#       Title    Gross
# 47   WALL·E  1162284
# 888  WALL·E  1162284

# %%
#11) how many animes belongs to PG certificate?
x=datax.loc[datax["Certificate"]=="PG",["Title"]].shape
x
# Out:
# (425, 1)

# %%
#12) what is the average no.of votes in your dataset.
datax["Number of Votes"].mean()
# not geting answer
